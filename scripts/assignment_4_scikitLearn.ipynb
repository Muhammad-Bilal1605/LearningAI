# %%
import sklearn
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
import  matplotlib.pyplot as plt

from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# # Load this dataset and visualize it

# %%
df=pd.read_csv("/Users/Bilal/PycharmProjects/LearningAI/Files/assignment_4/insurance.csv")

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# # Split the data into test (30%), train (60%), and validation (10%). Randomize/Shuffle the data and visualize it.

# %% [markdown]
# ## Making inputs and outputs

# %%
X=df.drop(columns=["charges"])
X.head()
# Out:
#     age     sex     bmi  children smoker     region
# 0    19  female  27.900         0    yes  southwest
# 1    18    male  33.770         1     no  southeast
# 2    28    male  33.000         3     no  southeast
# 3    33    male  22.705         0     no  northwest
# 4    32    male  28.880         0     no  northwest
# 5    31  female  25.740         0     no  southeast
# 6    46  female  33.440         1     no  southeast
# 7    37  female  27.740         3     no  northwest
# 8    37    male  29.830         2     no  northeast
# 9    60  female  25.840         0     no  northwest
# 10   25    male  26.220         0     no  northeast
# 11   62  female  26.290         0    yes  southeast
# 12   23    male  34.400         0     no  southwest
# 13   56  female  39.820         0     no  southeast
# 14   27    male  42.130         0    yes  southeast
# 15   19    male  24.600         1     no  southwest
# 16   52  female  30.780         1     no  northeast
# ...

# %%
y= df['charges']
y.head()
y.info
# Out:
# <bound method Series.info of 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64>

# %% [markdown]
# ## splitting into training 60 percent and testing 40 percent

# %%
X_train,X_test,y_train,y_test= train_test_split(X,y,random_state=22,shuffle=True,test_size=0.4)

# %%
X_train.info
# Out:
# <bound method DataFrame.info of       age     sex     bmi  children smoker     region
# 41     31  female  36.630         2     no  southeast
# 1334   18  female  31.920         0     no  northeast
# 1165   35  female  26.125         0     no  northeast
# 1227   42    male  37.180         2     no  southeast
# 1147   20  female  31.920         0     no  northwest
# ...   ...     ...     ...       ...    ...        ...
# 356    46    male  43.890         3     no  southeast
# 960    19  female  39.615         1     no  northwest
# 812    54    male  21.010         2     no  southeast
# 132    53  female  35.900         2     no  southwest
# 885    32    male  28.930         1    yes  southeast
#
# [802 rows x 6 columns]>

# %%
y_train.info
# Out:
# <bound method Series.info of 41       4949.75870
# 1334     2205.98080
# 1165     5227.98875
# 1227     7162.01220
# 1147     2261.56880
#            ...
# 356      8944.11510
# 960      2730.10785
# 812     11013.71190
# 132     11163.56800
# 885     19719.69470
# Name: charges, Length: 802, dtype: float64>

# %% [markdown]
# ## splitting the test to validation making a 60,30,10 split

# %%
X_test,X_validation,y_test,  y_validation= train_test_split(X_test,y_test,random_state=22,shuffle=True,test_size=0.25)

# %%
X_test.info
# Out:
# <bound method DataFrame.info of       age     sex     bmi  children smoker     region
# 61     25    male  33.660         4     no  southeast
# 818    47  female  26.125         1    yes  northeast
# 755    31    male  27.645         2     no  northeast
# 739    29    male  35.500         2    yes  southwest
# 183    44  female  26.410         0     no  northwest
# ...   ...     ...     ...       ...    ...        ...
# 1251   19    male  19.800         0     no  southwest
# 1321   62    male  26.695         0    yes  northeast
# 320    34    male  25.270         1     no  northwest
# 1053   47    male  29.800         3    yes  southwest
# 217    27    male  23.100         0     no  southeast
#
# [402 rows x 6 columns]>

# %%
X_validation.info
# Out:
# <bound method DataFrame.info of       age     sex     bmi  children smoker     region
# 208    63  female  31.800         0     no  southwest
# 981    34    male  21.375         0     no  northeast
# 369    18    male  30.400         3     no  northeast
# 193    56  female  26.600         1     no  northwest
# 1067   39    male  42.655         0     no  northeast
# ...   ...     ...     ...       ...    ...        ...
# 652    48  female  31.130         0     no  southeast
# 670    30    male  31.570         3     no  southeast
# 1149   42    male  34.100         0     no  southwest
# 1322   62    male  38.830         0     no  southeast
# 253    27    male  30.300         3     no  southwest
#
# [134 rows x 6 columns]>

# %% [markdown]
# # Use StandardScaler and MinMaxScaler
# from sklearn.preprocessing to scale the numerical features (e.g., age, bmi, charges).
# Visualize the effect of both scaling techniques using histograms
#
#
# ## why we do scaling ?
# we do scaling as in input data the numerical values range a lot like it can range to 400 500 and eve thousand making a model trained from it not good so to reduce that we scale the features so that the values are in a set range
#
# ## on what dat a do we do scaling
# on numbers data wont work on string

# %% [markdown]
# ## before scaling histogram
# as you can see the values range from 0 to 60

# %%
plt.hist(X_train[["age","bmi","children"]].to_numpy().flatten(), bins=10, color="blue",edgecolor="black")
# Out:
# (array([802.,   0., 101., 261., 430., 348., 150., 129.,  96.,  89.]),
#  array([ 0. ,  6.4, 12.8, 19.2, 25.6, 32. , 38.4, 44.8, 51.2, 57.6, 64. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## standard Scaler
# standard scaler makes the. values have mean of 0 and standard deviation of 1 in simple words it is not limited to 0 and 1 and can include negative values and even values greater than 1 as you can see in the output as well as the histogram
#
# ### Use it for:
#
# 1) Linear Regression
# 2) Logistic Regression
# 3) SVM
# 4) PCA
# 5) LDA
# 6) KNN
# 7) Neural Networks
#
# ### When NOT to use StandardScaler
# Tree-based models
#
# 1) They don’t care about feature scale:
# 2) Decision Tree
# 3) Random Forest
# 4) XGBoost
# 5) LightGBM

# %%
standardScaler=StandardScaler()
x1=standardScaler.fit_transform(X_train[["age","bmi","children"]])
X_train[["age","bmi","children"]]=pd.DataFrame(x1,columns=["age","bmi","children"])

# %%
X_train.head(5)
# Out:
#            age     sex       bmi  children smoker     region
# 41    0.755796  female -0.567617 -0.071199     no  southeast
# 1334       NaN  female       NaN       NaN     no  northeast
# 1165       NaN  female       NaN       NaN     no  northeast
# 1227       NaN    male       NaN       NaN     no  southeast
# 1147       NaN  female       NaN       NaN     no  northwest

# %%
plt.hist(X_train[["age","bmi","children"]].to_numpy().flatten(), bins=8, color="yellow",edgecolor="black")
# Out:
# (array([ 19., 399., 273., 335., 266., 141.,  18.,  13.]),
#  array([-2.39503602, -1.63285968, -0.87068334, -0.108507  ,  0.65366934,
#          1.41584568,  2.17802202,  2.94019836,  3.7023747 ]),
#  <BarContainer object of 8 artists>)

# %% [markdown]
# ## MinMax Scaler
# it gives values in the 0-1 range as seen in the ouput and histogram
# ### When to use MinMaxScaler
#
# 1) When you want all features in a fixed range, usually 0–1.
#
# 2) Useful for algorithms sensitive to scale:
#
# 3) Neural Networks (sigmoid, tanh activations)
#
# 4) KNN, K-Means
#
# 5) Gradient-based optimization
#
# ### Don’t use if:
#
# 1) Outliers are present (they’ll shrink other values)
#
# 2) Tree-based models (Decision Tree, Random Forest) — they don’t need scaling.

# %%
minmax=MinMaxScaler(feature_range=(0,1))
x2=minmax.fit_transform(X_train[["age","bmi","children"]])
X_train[["age","bmi","children"]]=pd.DataFrame(x2,columns=["age","bmi","children"])

# %%
X_train.head()
# Out:
#       age     sex  bmi  children smoker     region
# 41    NaN  female  NaN       NaN     no  southeast
# 1334  NaN  female  NaN       NaN     no  northeast
# 1165  NaN  female  NaN       NaN     no  northeast
# 1227  NaN    male  NaN       NaN     no  southeast
# 1147  NaN  female  NaN       NaN     no  northwest

# %%
plt.hist(X_train[["age","bmi","children"]].to_numpy().flatten(), bins=5,color="red",edgecolor="black")
# Out:
# (array([242., 280., 198., 112.,  68.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  <BarContainer object of 5 artists>)

# %% [markdown]
# # The dataset has categorical columns like sex, smoker, and region.
# Use LabelEncoder and OneHotEncoder from sklearn.preprocessing to encode these features.

# %% [markdown]
# ## OneHotEncoder
# one hot coder is basically used for data that have no co relation like city name etc, example like if we have some column that has a few values like big,medium,small or male,female n our case then we wont use one hot encoder as then we have data that have defined categories
